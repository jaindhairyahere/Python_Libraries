# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.image as mpimg
import numpy as np
import matplotlib as mpl
mpl.get_backend()
# Out:
# 'nbAgg'

# %%
def drawContour(data1,data2,data3,lev):
    '''
    param: data1 :
        X data - np.array
    param: data2 :
        Y data - np.array
    param: data3 :
        Z data - np.meshgrid
    param: levels :
    '''
    
    plt.contour(data1,data2,data3,levels=lev,cmap='hot')
    plt.colorbar()

# %%
X = np.array([1,2,3,4])
Y = np.array([1,2,3,4,5])
Z = np.ones([len(Y),len(X)])
for i in range(len(Y)):
    for j in range(len(X)):
        Z[i][j] = np.sin((i+1)*(j+2))
print(Z)
# Out:
# [[ 0.90929743  0.14112001 -0.7568025  -0.95892427]
#  [-0.7568025  -0.2794155   0.98935825 -0.54402111]
#  [-0.2794155   0.41211849 -0.53657292  0.65028784]
#  [ 0.98935825 -0.53657292 -0.28790332  0.91294525]
#  [-0.54402111  0.65028784  0.91294525 -0.13235175]]

# %%
drawContour(X,Y,Z,0)
# Out:
# <img src="data:image/png;base64,..." width="640">
